# %% [markdown]
# <a href="https://colab.research.google.com/github/SidharthArya/Deep_Learning_Class_Manit/blob/main/Assignments/005_Transfer_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from matplotlib import cycler
colors = cycler('color',
                ['#EE6666', '#3388BB', '#9988DD',
                 '#EECC55', '#88BB44', '#FFBBBB'])
plt.rc('axes', facecolor='#E6E6E6', edgecolor='none',
       axisbelow=True, grid=True, prop_cycle=colors)
plt.rc('grid', color='w', linestyle='solid')
plt.rc('xtick', direction='out', color='gray')
plt.rc('ytick', direction='out', color='gray')
plt.rc('patch', edgecolor='#E6E6E6')
plt.rc('lines', linewidth=2)

# %% [markdown]
# # Transfer Functions

# %% [markdown]
# ## Linear

# %%
def linear(x):
  return x

# %%
x=np.arange(-2,2,0.01)
plt.axhline(0,color='grey') 
plt.axvline(0,color='grey') 
plt.plot(x, linear(x))

# %% [markdown]
# ## ReLu

# %%
# ReLu

def reLu(x):
  return np.array([xi if xi >= 0 else 0 for xi in x])

# %%
x=np.arange(-2,2,0.01)
plt.axhline(0,color='grey') 
plt.axvline(0,color='grey') 
plt.plot(x, reLu(x))

# %% [markdown]
# # LeakyReLu

# %%
def leakyReLu(x, negative_slope=0.01):
  return np.array([xi if xi>=0 else xi*negative_slope for xi in x])

# %%
x=np.arange(-2,2,0.01)
plt.axhline(0,color='grey') 
plt.axvline(0,color='grey') 
plt.plot(x, leakyReLu(x))

# %%
x=np.arange(-2,2,0.01)
plt.axhline(0,color='grey') 
plt.axvline(0,color='grey') 
plt.plot(x, leakyReLu(x, negative_slope=0.1))

# %% [markdown]
# ## Sigmoid

# %%
def sigmoid(x, lam=1):
  return 1/(1+np.exp(-lam*x))

# %%
x=np.arange(-10,10,0.005)
plt.axhline(0,color='grey') 
plt.axvline(0,color='grey') 
plt.plot(x, sigmoid(x))

# %%
# With a different lambda
x=np.arange(-10,10,0.005)
plt.axhline(0,color='grey') 
plt.axvline(0,color='grey') 
plt.plot(x, sigmoid(x,10))

# %% [markdown]
# ## Exponential Linear Unit (ELU)

# %%
def eLU(x, alpha=1):
  return np.array([xi if xi>0 else alpha*(np.exp(xi)-1) for xi in x ])

# %%
x=np.arange(-10,10,0.01)
plt.axhline(0,color='grey') 
plt.axvline(0,color='grey') 
plt.plot(x, eLU(x))

# %%
# With a different alpha
x=np.arange(-2,2,0.01)
plt.axhline(0,color='grey') 
plt.axvline(0,color='grey') 
plt.plot(x, eLU(x,5))

# %% [markdown]
# ## LogSigmoid

# %%
def logsigmoid(x, lam=1):
  return np.log(1/(1+np.exp(-lam*x)))

# %%
x=np.arange(-10,10,0.01)
plt.axhline(0,color='grey') 
plt.axvline(0,color='grey') 
plt.plot(x, logsigmoid(x))

# %%
# With a different lambda
x=np.arange(-10,10,0.01)
plt.axhline(0,color='grey') 
plt.axvline(0,color='grey') 
plt.plot(x, logsigmoid(x,5))

# %% [markdown]
# ## Tanh

# %%
def tanh(x, lam=1):
  return (np.exp(lam*x)-np.exp(-lam*x))/(np.exp(lam*x)+np.exp(-lam*x))

# %%
# With a different lambda
x=np.arange(-2,2,0.01)
plt.axhline(0,color='grey') 
plt.axvline(0,color='grey') 
plt.plot(x, tanh(x))

# %%
# With a different lambda
x=np.arange(-2,2,0.01)
plt.axhline(0,color='grey') 
plt.axvline(0,color='grey') 
plt.plot(x, tanh(x, 5))

# %% [markdown]
# ## Polynomial

# %%
x = np.arange(-50,50,0.05)

# %%
f1 = x**2 + 5*x  + 1

# %%
plt.axhline(0,color='grey') 
plt.axvline(0,color='grey') 
plt.plot(x,f1)

# %%
f2 = x**3 + 5*x  + 1

# %%
plt.axhline(0,color='grey') 
plt.axvline(0,color='grey') 
plt.plot(x,f2)

# %% [markdown]
# # Swish (or SiLu, Sigmoid Linear unit)
# - It was introduced by Google.
# - It performs better than ReLU.
# - It is non-monotonic.

# %%
def silu(x,beta=1):
  return x*sigmoid(beta*x)

# %%
plt.axhline(0,color='grey') 
plt.axvline(0,color='grey') 
plt.plot(x,silu(x))

# %%
plt.axhline(0,color='grey') 
plt.axvline(0,color='grey') 
plt.plot(x,silu(x, beta=100))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp

# %% [markdown]
# # Softmax
# - For softmax, value at a point is dependent on all other points
# - Sum of all values is 1
# - Converts to probabilities

# %%
def softmax(x):
  return np.exp(x)/np.exp(x).sum()

# %%
plt.axhline(0,color='grey') 
plt.axvline(0,color='grey') 
plt.plot(x,softmax(x))
